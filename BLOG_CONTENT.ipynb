# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 47.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.9 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")

# %%
model = GPT2LMHeadModel.from_pretrained("gpt2-large", pad_token_id=tokenizer.eos_token_id)

# %%
user_input = input("Enter your blog prompt: ")
# Out:
# Enter your blog prompt: ARTIFICIAL INTELLIGENCE

# %%
sentence = user_input

# %%
input_ids = tokenizer.encode(sentence, return_tensors='pt')

# %%
input_ids
# Out:
# tensor([[ 7227, 30643, 12576,  3268,  9328,  3069,  3528, 18310]])

# %%
output = model.generate(input_ids, max_length=50, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)

# %%
output
# Out:
# tensor([[ 7227, 30643, 12576,  3268,  9328,  3069,  3528, 18310, 13077, 24181,
#          11015,    13,   357,    64,     8, 35263,   286, 37552,  9816,  1858,
#            389, 10435,   284,   307, 32316,   284,   262,  2732,   286,  5947,
#            329,  9068,   614,  2177,   884, 21784,   355,   743,   307,  3306,
#            284,  7139,   262,  5890,   286,  2351,  9345,   284,  3283,   503]])

# %%
context=tokenizer.decode(output[0], skip_special_tokens=True)
print(context)
# Out:
# ARTIFICIAL INTELLIGENCE AGENCIES. (a) Authorization of Appropriations.--There are authorized to be appropriated to the Department of Defense for fiscal year 2017 such sums as may be necessary to enable the Director of National Intelligence to carry out

# %%
from IPython.display import HTML, display
context = tokenizer.decode(output[0], skip_special_tokens=True)
html_content = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Generated Blog</title>
</head>
<body>
    <h1>Generated Blog</h1>
    <p>{context}</p>
</body>
</html>
"""
file_name = "generated_blog.html"
with open(file_name, "w") as file:
    file.write(html_content)

# Create a link to open the HTML file in a new tab
html_link = f'<a href="{file_name}" target="_blank">Open Generated Blog</a>'

# Display the link
display(HTML(html_link))
# Out:
# <a href="generated_blog.html" target="_blank">Open Generated Blog</a>
